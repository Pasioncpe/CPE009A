# %% [markdown]
# <a href="https://colab.research.google.com/github/Pasioncpe/CPE009A/blob/main/HOA_1_1_CPE009_PASION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**HOA 1.1 / CPE009**
#
# Literals, Operators, and Variables
#
# Pasion, Al Twain D. / 2516562
#
# Engr. Maria Rizzete Sayo

# %% [markdown]
# # **Assigning variables of differnet data types in Python:**

# %%
#1
value=5
print(value)
# Out:
# 5

# %%
#2
type(value)
# Out:
# int

# %%
#3
value=5.0
print(value)
# Out:
# 5.0

# %%
#4
type(value)
# Out:
# float

# %%
#5.a
value = 2 + 3j
print(value)
# Out:
# (2+3j)

# %%
#5.a
type(value)
# Out:
# complex

# %%
#5.b
value = 'Hello World'
print(value)
# Out:
# Hello World

# %%
#5.b
type(value)
# Out:
# str

# %%
#5.c
value = "Hello World"
print(value)
# Out:
# Hello World

# %%
#5.c
type(value)
# Out:
# str

# %%
#5.d
value = True
print(value)
# Out:
# True

# %%
#5.d
type(value)
# Out:
# bool

# %%
#5.e
value = False
print(value)

# %%
#5.e
type(value)
# Out:
# bool

# %%
#5.f
value = [1,2,3,4,5]
print(value)
# Out:
# [1, 2, 3, 4, 5]

# %%
#5.f
type(value)
# Out:
# list

# %%
#5.g
value = (1,2,3,4,5)
print(value)
# Out:
# (1, 2, 3, 4, 5)

# %%
#5.g
type(value)
# Out:
# tuple

# %%
#5.h
value = { 'name': 'Your_name' }
print(value)
# Out:
# {'name': 'Your_name'}

# %%
#5.h
type(value)
# Out:
# dict

# %%
#5.i
value = None
print(value)
# Out:
# None

# %%
#5.i
type(value)
# Out:
# NoneType

# %%
#6
value = 5

# %%
#7
value2 = -6

# %% [markdown]
# # **Performing Operations with Python**

# %%
#1
print(value+value2)
# Out:
# -1

# %%
#2.a
value, value2 = 5.0, 6
print(value+value2)
print(value-value2)
# Out:
# 11.0
# -1.0

# %%
#2.b
value, value2 = -5, 6.1
print(value+value2)
print(value-value2)
# Out:
# 1.0999999999999996
# -11.1

# %%
#2.c
value, value2 = "Hello ", 'world'
print(value+value2)
print(value-value2)
# Out:
# Hello world
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4293367326.py in <cell line: 0>()
#       2 value, value2 = "Hello ", 'world'
#       3 print(value+value2)
# ----> 4 print(value-value2)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
#2.d
value, value2 = [1,2,3], [4,5,6]
print(value+value2)
print(value-value2)
# Out:
# [1, 2, 3, 4, 5, 6]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4247544719.py in <cell line: 0>()
#       2 value, value2 = [1,2,3], [4,5,6]
#       3 print(value+value2)
# ----> 4 print(value-value2)
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
#2.e
value, value2 = (1,2,3), (4,5,6)
print(value+value2)
print(value-value2)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
#2.f
value, value2 = {'name':'Royce'}, {'age':2}
print(value+value2)
print(value-value2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-974266138.py in <cell line: 0>()
#       1 #2.f
#       2 value, value2 = {'name':'Royce'}, {'age':2}
# ----> 3 print(value+value2)
#       4 print(value-value2)
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
#3
value, value2 = 30, 4

# %%
#3.a
print(value*value2)
# Out:
# 120

# %%
#3.b
print(value2**2)
# Out:
# 16

# %%
#3.c
print(value2**3)
# Out:
# 64

# %%
#3.d
print(value*value2+value2**2+1)
# Out:
# 137

# %%
#3.e
print(value/value2)
# Out:
# 7.5

# %%
#3.f
print(value%value2)
# Out:
# 2

# %% [markdown]
# # **Receiving Input Data using Python / Assigning Input Data to a Variable**

# %%
#1
name = input("Enter your name: ")
#2 #5
weight = float(input("Enter your weight(kg): "))
#3 #5
height = float(input("Enter your height(m): "))

#4
bmi = weight/(height**2)

print( "Name: ",name)
print("Weight: ",weight)
print("Height: ",height)
print("BMI: ",bmi)
# Out:
# Enter your name: Pasion
# Enter your weight(kg): 69
# Enter your height(m): 1.67
# Name:  Pasion
# Weight:  69.0
# Height:  1.67
# BMI:  24.740937287102444

# %% [markdown]
# **SUPPLEMENTARY ACTIVITY**

# %%
#1

base, height, area = 0, 0, 0

base = float(input("Enter the base of the triangle: "))
height = float(input("Enter the height of the triangle: "))

area = (1/2) * base * height

print("The area of the triangle is: ", area)

# %%
#2
cel, fah = 0, 0
cel = float(input("Enter the temperature in Celsius: "))
fah = (cel * 9/5) + 32
print("The temperature in Fahrenheit is: ", fah)

# %%
#3

x1, x2, y1, y2 = 0, 0, 0, 0

x1 = float(input("Enter the x-coordinate of the first point: "))
x2 = float(input("Enter the x-coordinate of the second point: "))

y1 = float(input("Enter the y-coordinate of the first point: "))
y2 = float(input("Enter the y-coordinate of the second point: "))

d = ((x2 - x1)**2 + (y2 - y1)**2)**1/2

print("The distance between the two points is: ", d)
# Out:
# Enter the x-coordinate of the first point: 2
# Enter the x-coordinate of the second point: 3
# Enter the y-coordinate of the first point: 3
# Enter the y-coordinate of the second point: 1
# The distance between the two points is:  2.5

# %% [markdown]
# # **Questions:**
#
# 1. Give one major difference in syntax that Python has with other languages such as C?
#
# One Major Change I observed with Python's syntax and other languages like C++ is the use of ";", you barely use it in basic tasks.
#
# ---
#
# 2. How does variable assignment differ in Python compared with other languages such as C?
#
# Compare to other languages, Python's variable assigning is almost instantaneous. It can be all added in one line and the data type is assigned autonomously
#
# ---
#
# 3. Try assigning variable names that start with numbers, and special characters. Is the assigning of variables that start with numbers accepted by Python? For Special Characters? Is there an exception for variables special characters?
#
# The variables starting with numbers and special characters are deemed as an invalid syntax. There is no exceptions with special characters except for underscores (_). A variable must start with a letter or an underscore with no spaces and then you can put numbers after.
#
# ---
#
# 4. Do the assignment operators (+, -, *, /, %, **) work for all data types? Why or Why not?
#
# No, unlike integers, some operators only work for other data types. For example, the operators (+) and (*) may work for strings since it only combines the words and multiplies them respectively, but for any other operators it will be deemed as an error.
#
# ---
#
# 5. How does the * operator differ from the ** operator?
#
# The (*) operator performs multiplication between numbers and the (**) does exponentiation, meaning raising the first value to the power of the second.
