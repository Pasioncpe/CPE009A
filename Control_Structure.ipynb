# %% [markdown]
# 1. If statement

# %%
a = 12
b = 100

if b > a:
    print("b is greater than a")
# Out:
# b is greater than a

# %% [markdown]
# 2. Elif Statement

# %%
a = 12
b = 12
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
# Out:
# a and b are equal

# %% [markdown]
# 3. Else Statement

# %%
a = 200
b = 33

if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# 4. Short Hand If Statement

# %%
if a > b: print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# 5. Short Hand If..Else Statement

# %%
a = 2
b = 330

print("A") if a > b else print("B")
# Out:
# B

# %% [markdown]
# 6. And-both conditions are true

# %%
a = 200
b = 33
c = 500

if a > b and c > a:
  print("Both conditions are True")
# Out:
# Both conditions are True

# %% [markdown]
# 7. Or-at least one of the conditions is true

# %%
a = 200
b = 33
c = 500

if a > b or a > c:
  print("At least one of the conditions is True")
# Out:
# At least one of the conditions is True

# %% [markdown]
# 8. Nested If

# %%
x = 41

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20")
    if x > 30:
      print("and also above 30")
      if x > 40:
        print("and also above 40")
        if x > 50:
          print("and also above 50")
        else:
          print("but below 50")
else:
  print("below 10")


# +5 points
# Out:
# Above ten,
# and also above 20
# and also above 30
# and also above 40
# but below 50

# %% [markdown]
# Example 3

# %%
grade = float(input("Enter your grade: "))

if grade < 0: print("Invalid Input")
elif grade >= 75: print("Passed")
elif grade == 74: print("Remedial")
elif grade < 74: print("Failed")

# +5 Points
# Out:
# Enter your grade: 0
# Failed
